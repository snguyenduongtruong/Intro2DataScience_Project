# %%
from IPython.display import HTML

table_html = """
<table style="width: 100%; border-collapse: collapse;", justify="center">
  <thead>
    <tr>
      <td style="text-align: center;">Thành viên</th>
      <td style="text-align: center;">Gặp những khó khăn gì?</th>
      <td style="text-align: center;">Đã học được những gì?</th>
      <td style="text-align: center;">(Cả nhóm) Nếu có thêm thời gian thì làm gì?</th>
    </tr>
  </thead>
  <tbody>
    <tr>
      <td> 21120110 <br> Nguyễn Tấn Phát</td>
      <td style="text-align: left;"> NaN </td>
      <td style="text-align: left;"> NaN </td>
      <td style="text-align: left;"> NaN </td>
    </tr>
    <tr>
      <td>21120115 <br> Nguyễn Trọng Phúc </td>
      <td style="text-align: left;">+ Trong quá trình đặt câu hỏi đề xuất: 
        số lượng thuộc tính tương đối ít và rời rạc,  
        do đó việc đặt câu hỏi phù hợp, 
        có ý nghĩa thực tế có đôi chút khó khăn. <br> <br>
        + Trong quá trình tìm câu trả lời: do từng giai đoạn 
        là mỗi thành viên trong nhóm sẽ đảm nhận khác nhau, 
        nên trong quá trình tìm câu trả lời có xuất hiện một số cột dữ liệu
        không hợp lí, kiểu dữ liệu chưa phù hợp. Vì thế việc trao đổi với thành viên
        tiền xử lí dữ liệu và người đặt câu hỏi
        để hiểu rõ về dữ liệu trước khi khi đặt câu hỏi là rất quan trọng. <br> 
      </td>
      <td style="text-align: left;">
      + Kỹ năng làm việc nhóm: phân công công việc, theo dõi tiến độ đồ án, quản lí thời gian,… <br> <br>
      + Học được cách sử dụng Github trong việc quản lí đồ án, 
      trao đổi thông tin hiệu quả trong cập nhật thông tin đồ án. <br> <br>
      + Học thêm nhiều kinh nghiệm và kiến thức từ những thành viên khác trong nhóm.
      </td>
      <td style="text-align: left;">NaN</td>
    </tr>
    <tr>
      <td> 21120322 <br> Nguyễn Dương Trường Sinh</td>
      <td style="text-align: left;">
      + Đặt ra một vấn đề, một bài toán mô hình hóa dữ liệu là là câu chuyện hết sức phức tạp,
      khi mà phải có sự kết nối giữa mô hình học trên lý thuyết và tình hình thực tiễn. <br> <br>
      + Triển khai mô hình (model deployment) là chủ đề mới, bởi vì để đưa một mô hình lý thuyết
      của bài toán ra sản phẩm thực tế, phải tìm hiểu thêm nhiều kiến thức về software development, 
      vòng đời của một ứng dụng, MLOps, ...
      </td>
      <td style="text-align: left;">
      + Kiến thức mới về các công cụ, các thư viện mạnh mẽ của Python cho mô hình hóa dữ liệu và triển khai (deployment). <br> <br>
      + Triển khai thành công mô hình lên web app. <br> <br>
      + Các bước tiền xử lý dữ liệu đặc trưng cho việc mô hình hóa dữ liệu đó.  <br> <br>
      </td>
      <td style="text-align: left;">
      + Thiết kế sao cho phần deployment đẹp hơn, bắt mắt hơn cho người dùng. <br> <br>
      + Thử sức với parallel computing để chương trình chạy nhanh, mô hình học nhanh hơn.
      </td>
    </tr>
    <tr>
      <td> 20120515 <br> Luân Mã Khương</td>
      <td style="text-align: left;"> + Mất thời gian để phát hiện lỗi và sửa chữa.</td>
      <td style="text-align: left;"> + Học được nguyên lý hoạt động những mô hình học máy, 
      cách đánh giá mô hình để so sánh hiệu suất của các mô hình</td>
      <td style="text-align: left;"> + Nếu có thời gian sẽ bổ sung thêm những câu hỏi khó hơn, 
      giải quyết được những vấn đề phức tạp hơn</td>
    </tr>
    
  </tbody>
</table>
"""

HTML(table_html)
# Out:
# <table style="width: 100%; border-collapse: collapse;", justify="center">
#   <thead>
#     <tr>
#       <td style="text-align: center;">Thành viên</th>
#       <td style="text-align: center;">Gặp những khó khăn gì?</th>
#       <td style="text-align: center;">Đã học được những gì?</th>
#       <td style="text-align: center;">(Cả nhóm) Nếu có thêm thời gian thì làm gì?</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td> 21120110 <br> Nguyễn Tấn Phát</td>
#       <td style="text-align: left;"> NaN </td>
#       <td style="text-align: left;"> NaN </td>
#       <td style="text-align: left;"> NaN </td>
#     </tr>
#     <tr>
#       <td>21120115 <br> Nguyễn Trọng Phúc </td>
#       <td style="text-align: left;">+ Trong quá trình đặt câu hỏi đề xuất:
#         số lượng thuộc tính tương đối ít và rời rạc,
#         do đó việc đặt câu hỏi phù hợp,
#         có ý nghĩa thực tế có đôi chút khó khăn. <br> <br>
#         + Trong quá trình tìm câu trả lời: do từng giai đoạn
# ...

# %% [markdown]
# - **Sheet phân công công việc:**
#
# https://docs.google.com/spreadsheets/d/1o24XX7BsF2ycCQmSwk5KANs6ON31E81_-SoW30axZ2w/edit?usp=sharing
#
# - **Github của nhóm:**
#
# https://github.com/snguyenduongtruong/Intro2DataScience_Project.git
